# %%
import numpy as np
import matplotlib.pyplot as plt

p = 1/2
n = np.arange(0,10)
X = np.power(p, n)
plt.bar(n, X);

# %%
plt.hist(X, cumulative=True);

# %%
from scipy.special import comb, factorial
n=10
k=2
comb(n,k)
# Out:
# 45.0

# %%
factorial(k)
# Out:
# 2.0
